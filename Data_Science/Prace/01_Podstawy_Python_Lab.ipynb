# %%
# age = 23
age = 28

if age >= 18:
    print("Jestes dorosły")
else:
    print("Jesteś za młody")

isDrunk = False # zmienna logiczna, czy osoba jest trzeźwa

if age >= 18 and not isDrunk:
    print("Jesteś trzeżwy i dorosły")
else:
    print("Jesteś nietrzeźwy")

isRestriction = False

if age >= 18 and not isDrunk and not isRestriction:
    print("Jesteś trzeżwy i dorosły")
else:
    print("Jesteś nietrzeźwy")
# Out:
# Jestes dorosły
# Jesteś trzeżwy i dorosły
# Jesteś trzeżwy i dorosły

# %%
ileLike = 400
ileSharch = 100

if ileLike >= 500 and ileSharch >= 100:
    print("Ceny obniżone o 10%")
else: 
    print("Stała cena")
# Out:
# Stała cena

# %%
isPizzaOrdered = True
isBigDrinkOrdered = True
isWeekend = False

if (isPizzaOrdered and isBigDrinkOrdered) and not isWeekend:
    print("Otrzymujesz kupon na Burgera")
else:
    print("Zachęcamy do dalszych zakupów")
# Out:
# Otrzymujesz kupon na Burgera

# %%
diskSize = 140
diskSizeUsed = 133
fileSize = 2
NeedDisc = diskSizeUsed + fileSize


if NeedDisc <= 140:
    print("Miejsca jest wysatrczająco")
else:
    print("Za mało miejsca")
# Out:
# Miejsca jest wysatrczająco

# %%
ileLike = 600
ileSharch = 90

if ileLike >= 500 and ileSharch >= 100:
    print("Ceny obniżone o 10%")
elif ileLike < 500: 
    print("Brak wystarczającej ilości like")
else:
    print("Brak wystarczającej ilości udostępień")
# Out:
# Brak wystarczającej ilości udostępień

# %%
isPizzaOrdered = True
isBigDrinkOrdered = False
isWeekend = True

if (isPizzaOrdered and isBigDrinkOrdered) and not isWeekend:
    print("Otrzymujesz kupon na Burgera")
elif (isPizzaOrdered and isBigDrinkOrdered and isWeekend):
    print("Promocja obowiązuje wyłacznie w weekend")
else:
    print("Należy zamówić pizze lub napój")
# Out:
# Należy zamówić pizze lub napój

# %%
# Napisz program, który obliczy wskaźnik BMI (Body Mass Index).
# Wymagania:
# Stwórz zmienne waga i wzrost
# Oblicz BMI według wzoru: BMI = waga / (wzrost²)
# Wyświetl wynik z 2 miejscami po przecinku
# Dodaj interpretację: BMI < 18.5 (niedowaga), 18.5-24.9 (norma), ≥25 (nadwaga)

waga = 70
wzrost = 1.75
BMI = waga / (wzrost**2)
print(f'BMI {BMI:.2f}') # 2 miejsca po przecinku
if BMI < 18.5:
    print('Niedowaga')
elif BMI >= 18.5:
    print('Norma')
elif BMI >= 25:
    print('Nadwaga')

# # elif BMI > 25
# #     print('Norma')
# # else:
# #     print('Nadwaga')
# Out:
# BMI 22.86
# Norma

# %%
# Napisz program konwertujący temperatury Celsius na Fahrenheit i Kelvin.
# Dane:
#   Temperatura: 23.5°C
# Wymagania:
# - Fahrenheit = Celsius × 9/5 + 32
# - Kelvin = Celsius + 273.15
# - Wyświetl wszystkie 3 wartości sformatowane z 1 miejscem po przecink
# Oczekiwany rezultat
#   23.5°C = 74.3°F = 296.6 K
temp = 23.5
print(f"Temperatura =: {temp}")
Fah = temp * (9/5) + 32
print(f"Fahrenheit =: {Fah:.1f}")
Kel = temp + 273.15
print(f"Kelvin =: {Kel:.1f}")
# Out:
# Temperatura =: 23.5
# Fahrenheit =: 74.3
# Kelvin =: 296.6

# %%
# Oblicz rozmiary zbiorów treningowego, walidacyjnego i testowego.
# Dane: Całkowita liczba próbek: 1000
# Proporcje: 70% trening, 15% walidacja, 15% test
# Wymagania:
# Użyj mnożenia i dzielenia całkowitego
# Upewnij się, że suma = 1000 (obsłuż resztę z dzielenia)
# Wyświetl rozmiary wszystkich zbiorów

L_próbek = 1000
trening = L_próbek * 70 // 100
print(f"Trening wynosi {trening}")
walidacja = L_próbek * 15 // 100
print(f"Walidacja wynosi {walidacja}")
test = L_próbek - walidacja - trening
print(f"Test wynosi {test}")
# Out:
# Trening wynosi 700
# Walidacja wynosi 150
# Test wynosi 150

# %%
# Oblicz learning rate dla schedulera.
# Dane:
# Początkowy learning rate: 0.1
# Współczynnik decay: 0.95
# Numer epoki: 10
# Wymagania:
# Użyj wzoru: lr_new = lr_initial × (decay ^ epoch)
# Operator potęgowania **
# Wyświetl wynik w notacji naukowej ( .2e )
learning_rate = 0.1
decay = 0.95
epoch = 10
lr_new = learning_rate * (decay ** epoch)
print(f"Learning rate po 10 epokach wynosi {lr_new:.2e}")
# Out:
# Learning rate po 10 epokach wynosi 5.99e-02

# %%
# Ustandaryzuj nazwę kolumny z datasetu.
# Wymagania:
# Usuń białe znaki
# Zamień na małe litery
# Zastąp _ przez " "
# Użyj title case
Nazwa_raw = " PATIENT_age_YEARS "
Nazwa_clean = Nazwa_raw.strip()
print(f"Orginał: '{Nazwa_raw}'")
print(f"Po strip(): '{Nazwa_clean}'")

print(Nazwa_clean.lower())

Nazwa_standard = Nazwa_clean.replace("_", " ")
print(f"Standaryzowana: '{Nazwa_standard}'")

print(Nazwa_standard.title())
# Out:
# Orginał: ' PATIENT_age_YEARS '
# Po strip(): 'PATIENT_age_YEARS'
# patient_age_years
# Standaryzowana: 'PATIENT age YEARS'
# Patient Age Years

# %%
# Sformatuj metryki modelu.
# Wymagania:
# Wyświetl każdą metrykę w procentach z 2 miejscami po przecinku
# Użyj f-strings z formatowaniem :.2%
# Dodaj estetyczne wyrównanie kolum
Accuracy = 0.9234
Precision = 0.8891
Recall = 0.9456

print(f"Accuracy: {Accuracy:.2f}")
print(f"Precision: {Precision:.2f}")
print(f"Recall: {Recall:.2f}")

print(f"Accuracy: {Accuracy:.2%}")
print(f"Precision: {Precision:.2%}")
print(f"Recall: {Recall:.2%}")

headers = ["Accuracy", "Precision", "Recall"]
print(f"{headers[0]:<10} {headers[1]:>10} {headers[2]:>10}")
# Out:
# Accuracy: 0.92
# Precision: 0.89
# Recall: 0.95
# Accuracy: 92.34%
# Precision: 88.91%
# Recall: 94.56%
# Accuracy    Precision     Recall

# %%
# Znormalizuj wartość do zakresu [0, 1].
# Wymagania:
# Wzór: normalized = (value - min) / (max - min)
# Oblicz dla wartości 75, 50, 100, 62.5
# Sprawdź, czy wynik mieści się w [0, 1]
# Wyświetl tabelkę: wartość oryginalna | wartość znormalizowan
import math

Wartość = 50 # /Oblicz dla wartości 75, 50, 100, 62.5
Min = 50
Max = 100

Normalized = (Wartość - Min)/(Max - Min)
print(Normalized)

if 0 <= Normalized <=1:
    print("Wynik mieści się w zakresie [0,1]")
else:
    print("Wynik nie mieści się w zakresie [0,1]")

print(f"\nPomiary:")
print(f"Wartość: {Wartość}")
print(f"Wartość znormalizowana: {Normalized}")
# Out:
# 0.0
# Wynik mieści się w zakresie [0,1]
#
# Pomiary:
# Wartość: 50
# Wartość znormalizowana: 0.0
