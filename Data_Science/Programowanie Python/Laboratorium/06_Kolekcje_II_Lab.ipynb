# %%
values = [1,2,3,4,5,6]

res = []
for v in values:
    if v > 4:
        res.append(v)

print(res)
# Out:
# [5, 6]

# %%
#1
# Stwórz słownik osoba zawierający klucze: imie , nazwisko , wiek , miasto , email .
# Wypełnij go przykładowymi danymi i wypisz wszystkie informacje w czytelny sposób.
# Wymagania: Użyj f-stringów do formatowania, Wypisz każdą informację w osobnej linii

osoba = {'imie': 'Andrzej',
         'nazwisko': 'Kowal',
          'wiek': '39', 
          'miasto': 'Poznań', 
          'email': 'xxx@zz.com'
          }
print(f'Osoba: {osoba}')
tylko_imię = osoba['imie']
print(f"tylko_imię")
z_get = osoba.get('nazwisko', 'Nie istnieje')
print(z_get)
# Out:
# Osoba: {'imie': 'Andrzej', 'nazwisko': 'Kowal', 'wiek': '39', 'miasto': 'Poznań', 'email': 'xxx@zz.com'}
# tylko_imię
# Kowal

# %%
#3
# asz listę słów: ['python', 'java', 'python', 'javascript', 'python', 'java',
# 'c++', 'python'] . Policz ile razy każde słowo występuje używając słownika.
# Wymagania: Użyj pętli i metody .get()
# Wypisz wyniki

zmienna = ['python', 'java', 'python', 'javascript', 'python', 'java', 'c++', 'python']
słownik = {}
for jezyk in zmienna:
    # if jezyk not in słownik:
    #     słownik[jezyk] = 1 
    # else:
    #     słownik[jezyk] +=1
    słownik[jezyk] = słownik.get(jezyk, 0) +1
print(słownik)
# Out:
# {'python': 4, 'java': 2, 'javascript': 1, 'c++': 1}
