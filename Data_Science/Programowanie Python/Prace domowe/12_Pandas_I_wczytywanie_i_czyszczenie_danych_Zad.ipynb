# %%
# Stwórz DataFrame zawierający informacje o 10 produktach w sklepie: nazwa, cena, ilość na
# stanie, kategoria.
# Wymagania:
# Użyj słownika do utworzenia DataFrame
# Wyświetl pierwsze 5 wierszy
# Oblicz całkowitą wartość towaru (cena * ilość) i dodaj jako nową kolumnę
# -> DataFrame z 10 produktami i kolumną 'WartośćCałkowita'


import pandas as pd

produkty = {'nazwa': ['kawa','stolik', 'kubek', 'mleko'],
            'cena': [50,300,30,5],
            'ilosc': [300,8,100,40],
            'kategoria': ['napój', 'mebel', 'zastawa', 'napój']}
frame = pd.DataFrame(produkty)
print(frame)

frame.insert(loc=3,column='wartosc', value= frame.cena * frame.ilosc)
frame.head()
# Out:
#     nazwa  cena  ilosc kategoria
# 0    kawa    50    300     napój
# 1  stolik   300      8     mebel
# 2   kubek    30    100   zastawa
# 3   mleko     5     40     napój
#     nazwa  cena  ilosc  wartosc kategoria
# 0    kawa    50    300    15000     napój
# 1  stolik   300      8     2400     mebel
# 2   kubek    30    100     3000   zastawa
# 3   mleko     5     40      200     napój

# %%
# Wyczyść dataset Titanic stosując pełny pipeline:
# Wymagania:
# Usuń kolumny z >60% NaN
# Wypełnij Age medianą
# Wypełnij Embarked dominantą
# Usuń wiersze z pozostałymi NaN
# Przed i po: wypisz kształt DataFrame
# Sprawdź czy nie ma NaN
# Porównaj rozkład Age przed i po
import pandas as pd

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

titanic = pd.read_csv(url)
print(titanic)

threshold = len(titanic) * 0.4
titanic = titanic.dropna(thresh=threshold,axis=1)

kopia = titanic.copy()
titanic_mediana = kopia['Age'].median()
kopia['Age'] = kopia['Age'].fillna(titanic_mediana)

embarked_mode = kopia['Embarked'].mode()[0] 
kopia['Embarked'] = kopia['Embarked'].fillna(embarked_mode)
print(f"\nEmbarked po wypełnieniu dominantą ('{embarked_mode}'):")
print(kopia['Embarked'].value_counts())

kopia.dropna(axis='rows').head()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Stwórz nowe zmienne z Titanic:
# Wymagania:
# FamilySize = SibSp + Parch + 1
# IsAlone = 1 jeśli FamilySize == 1, inaczej 0
# AgeGroup = kategorie (0-12, 13-18, 19-35, 36-60, 60+)
# Dodaj wszystkie 3 zmienne do DataFrame
# Wyświetl value_counts() dla każdej
# Oblicz wskaźnik przeżycia dla IsAlone vs nie alone

import pandas as pd

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

titanic = pd.read_csv(url)
titanic_clean = titanic.copy()
print(titanic_clean)

titanic_clean['FamilySize'] = titanic_clean['SibSp'] + titanic_clean['Parch'] + 1
print(titanic_clean['FamilySize'].value_counts().head())

titanic_clean['IsAlone'] = (titanic_clean['FamilySize'] == 1).astype(int)
print(f"\nPasażerowie samotni: {titanic_clean['IsAlone'].sum()}")

przedzial_wiekowy = [0, 12, 18, 35, 60, 120]
kat = ['Dziecko', 'Nastolatek', 'Dorosły', 'Starszy', 'Senior']
titanic_clean["AgeGroup"] = pd.cut(titanic_clean['Age'], bins=przedzial_wiekowy, labels=kat)
print(titanic_clean['AgeGroup'].value_counts())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd 

dane = pd.read_csv('C:\\Users\\Alicja\\Desktop\\Pliki_DA_Udemy\\course-files\\Prestige.csv', index_col='name')
print(dane)
dane.rename(columns={'type': 'scientist'})
dane.columns

# Zbuduj serię o nazwie isScientist, zawierającą wartości True/False. True, jeśli odpowiadający wiersz w
# dane ma w kolumnie type wartość scientist, a False w przeciwnym wypadku. Wyświetl nagłówek
# dane.loc['chemists', 'type'] = 'scientist'
# isScientist = (dane["type"] == 'scientist')


dane.loc['chemists','prestige'] = 90
dane.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof
# ...                        ...     ...    ...       ...     ...   ...
# bus.drivers               7.58    5562   9.47      35.9    9171    bc
# taxi.drivers              7.93    4224   3.59      25.1    9173    bc
# longshoremen              8.37    4753   0.00      26.1    9313    bc
# typesetters              10.00    6462  13.58      42.2    9511    bc
# bookbinders               8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 6 columns]
#                      education  income  women  prestige  census  type
# name
# ...

# %%
import pandas as pd 
import numpy as np

dane = pd.read_csv('C:\\Users\\Alicja\\Desktop\\Pliki_DA_Udemy\\course-files\\Prestige.csv', index_col='name')
dane.columns

wiersz = pd.DataFrame({
        'education' : ['np.NaN'], 
        'income' : ['np.NaN'], 
        'women' : ['np.NaN'], 
        'prestige': ['np.NaN'], 
        'census': ['np.NaN'], 
        'type': ['np.NaN']
    }, index=['data scientist'])
dane = pd.concat([dane, wiersz])
dane.tail(5)
# Out:
#                education  income   women prestige  census    type
# taxi.drivers        7.93    4224    3.59     25.1    9173      bc
# longshoremen        8.37    4753     0.0     26.1    9313      bc
# typesetters         10.0    6462   13.58     42.2    9511      bc
# bookbinders         8.55    3617   70.87     35.2    9517      bc
# data scientist    np.NaN  np.NaN  np.NaN   np.NaN  np.NaN  np.NaN

# %%
import pandas as pd 
import numpy as np

dane = pd.read_csv('C:\\Users\\Alicja\\Desktop\\Pliki_DA_Udemy\\course-files\\Fortune_500_2017.csv')
# Zmień indeks na Rank. Wyświetl nagłówek
dane.set_index('Rank')
dane.head()   
# Wyświetl wiersze indeksowane między 100 a 105.  
dane[100:105]  
# Wyświetl wiersze indeksowane między 100 a 105, ale tym razem pokaż tylko kolumny "Title","Employees"
dane.loc[100:105][['Title','Employees']]
# Zmień indeks na Title w taki sposób aby nie utracić informacji z aktualnego indeksu (kolumna Rank). Wyświetl nagłówek
dane.reset_index(inplace=True)
dane.set_index('Title')
# Posortuj dane wg indeksu
dane.sort_index()
# Wyświetl firmy znajdujące się na indeksie między X a Y
dane.loc['X':'Y']
# Out:
# Empty DataFrame
# Columns: [index, Rank, Title, Website, Employees, Sector, Industry, Hqlocation, Hqaddr, Hqcity, Hqstate, Hqzip, Hqtel, Ceo, Ceo-title, Address, Ticker, Fullname, Revenues, Revchange, Profits, Prftchange, Assets, Totshequity]
# Index: []
#
# [0 rows x 24 columns]
