# %%
# Masz string CSV: "Alice,28,Data Scientist,75000" . Użyj split(',') aby wyciągnąć:
# Imię
# Wiek (jako int)
# Zawód
# Pensję (jako int)

tekst = "Alice,28,Data Scientist,75000"
# tekst_1 = tekst[0:5]
# print(f"Imię: {tekst_1}")
# tekst_2 = tekst[6:8]
# print(f"Wiek: {tekst_2}")
# tekst_3 = tekst[9:23]
# print(f"Zawód: {tekst_3}")
# tekst_4 = tekst[24:29]
# print(f"Pensja: {tekst_4}")
nowy_tekst = tekst.split(',')
print(nowy_tekst)
Imię, Wiek, Zawód, Pensja = tekst.split(',')
print(f'Imię: {Imię}')
print(f"Wiek: {Wiek}")
print(f'Zawós: {Zawód}')
print(f'Pensja: {Pensja}')
tekst_nowy = tekst.replace(",", " ")
print(tekst_nowy)
# Out:
# ['Alice', '28', 'Data Scientist', '75000']
# Imię: Alice
# Wiek: 28
# Zawós: Data Scientist
# Pensja: 75000
# Alice 28 Data Scientist 75000

# %%
# Masz nazwę pliku: "model_results_2024_Q3.csv" . Wyciągnij rok i kwartał.
nazwa = "model_results_2024_Q3.csv"
new_nazwa = nazwa.split('_')
x1, x2, rok, kwartal = nazwa.split('_')
kwartal = kwartal.split('.')[0]
# rok = nazwa[14:18]
print(f"Rok: {rok}")
# kwartal = nazwa[19:21]
print(f"Kwartał: {kwartal}")
# Out:
# Rok: 2024
# Kwartał: Q3

# %%
# Masz dane: model_name = "XGBoost" , accuracy = 0.8934 , time = 45.67 . Użyj f-
# string aby stworzyć raport:
model_name = "XGBoost , accuracy = 0.8934 , time = 45.67"
new_model = model_name.split(',')
nazwa,acc,time = model_name.split(',')
print(nazwa)
print(acc)
print(time)
# Out:
# XGBoost
#  accuracy = 0.8934
#  time = 45.67

# %%
# Masz listę transakcji (kategoria, kwota):
# Oblicz łączną kwotę dla każdej kategorii. Wynik zapisz w słowniku (użyj pętli i warunków)

transactions = [
('food', 50),
('transport', 20),
('food', 30),
('entertainment', 40),
('transport', 15),
('food', 25)
]
suma_category = {}
for category, amount in transactions:
    if category not in suma_category:
        suma_category[category] = 0
    suma_category[category] += amount
print(f"Suma wynosi: {suma_category}")
# Out:
# Suma wynosi: {'food': 105, 'transport': 35, 'entertainment': 40}

# %%
# Masz listę pomiarów: [23, 24, 22, 150, 23, 25, -10, 24, 23] . Outlierem jest wartość
# poza zakresem [20, 30]. Stwórz nową listę bez outlierów używając list comprehension

Pomiary = [23, 24, 22, 150, 23, 25, -10, 24, 23] 
poza_zakresem = [x for x in Pomiary if x < 20 or x > 30]
print(f"Nowa lista: {poza_zakresem}")
# Out:
# Nowa lista: [150, -10]

# %%
# Masz listę predykcji: ['spam', 'ham', 'spam', 'spam', 'ham', 'ham', 'spam'] .
# Policz ile jest 'spam' i ile 'ham' używając metody count()
lista = ['spam', 'ham', 'spam', 'spam', 'ham', 'ham', 'spam']
licz_ile = lista.count('spam')
licz_ile2 = lista.count('ham')
print(f'Spam wynosi: {licz_ile}')
print(f'Ham wynosi: {licz_ile2}')
# Out:
# Spam wynosi: 4
# Ham wynosi: 3
